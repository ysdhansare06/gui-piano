# %%
from tkinter import *
import time;
import datetime
import pygame

# %%
pygame.init()
root=Tk()
root.title("Music Box")
root.geometry('1352x700+0+0')
root.configure(background='white')

ABC = Frame(root, bg='powder blue', bd=20, relief=RIDGE)
ABC.grid()

ABC1 = Frame(root, bg='powder blue', bd=20, relief=RIDGE)
ABC1.grid()
ABC2 = Frame(root, bg='powder blue', relief=RIDGE)
ABC2.grid()
ABC3 = Frame(root, bg='powder blue', relief=RIDGE)
ABC3.grid()


str1 = StringVar()
str1.set("Music")
Date1 = StringVar()
Time1 = StringVar()

Date1.set(time.strftime('%d/%m/%Y'))
Time1.set(time.strftime('%H:%M:%S'))

def value_Cs():
    str1.set('C#')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\Db4.mp3")
    sound.play()

def value_Ds():
    str1.set('D#')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\Eb4.mp3")
    sound.play()

def value_Fs():
    str1.set('F#')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\Gb4.mp3")
    sound.play()

def value_Gs():
    str1.set('G#')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\Ab4.mp3")
    sound.play()

def value_As():
    str1.set('A#')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\Bb4.mp3")
    sound.play()

def value_Cs5():
    str1.set('C#')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\Db5.mp3")
    sound.play()

def value_Ds5():
    str1.set('D#')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\Eb5.mp3")
    sound.play()  
    
def value_C():
    str1.set('C')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\C4.mp3")
    sound.play()
    
def value_D():
    str1.set('D')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\D4.mp3")
    sound.play()

def value_E():
    str1.set('E')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\E4.mp3")
    sound.play()

def value_F():
    str1.set('F')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\F4.mp3")
    sound.play()
    
def value_G():
    str1.set('G')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\G4.mp3")
    sound.play()
    
def value_A():
    str1.set('A')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\A4.mp3")
    sound.play()
    
def value_B():
    str1.set('B')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\B4.mp3")
    sound.play()
    
def value_C5():
    str1.set('C')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\C5.mp3")
    sound.play()
    
def value_D5():
    str1.set('D')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\D5.mp3")
    sound.play()
    
def value_E5():
    str1.set('E')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\E5.mp3")
    sound.play()
    
def value_F5():
    str1.set('F')
    sound = pygame.mixer.Sound(r"C:\Users\Yash Dhansare\Downloads\piano-mp3-master\piano-mp3-master\piano-mp3\F5.mp3")
    sound.play()
#====================================== Label with Title =======================================

Label(ABC1, text="Piano Musical Keys", font=('arial',25,'bold'), padx=8,pady=8, bd=4, bg='powder blue',
      fg='black',justify=CENTER).grid(row=0,column=0,columnspan=11)

#===============================================================================================

texDate=Entry(ABC1, textvariable=Date1, font=('arial',18,'bold'),bd=4, bg='powder blue',
      fg='black', width=28, justify=CENTER).grid(row=1,column=0, pady=1)

texDisplay=Entry(ABC1, textvariable=str1, font=('arial',18,'bold'),bd=4, bg='powder blue',
      fg='black', width=28, justify=CENTER).grid(row=1,column=1, pady=1)

texTime=Entry(ABC1, textvariable=Time1, font=('arial',18,'bold'),bd=4, bg='powder blue',
      fg='black', width=28, justify=CENTER).grid(row=1,column=2, pady=1)

#================================================================================================

btnCs=Button(ABC2,height=6, width=6,bd=4, text="C#", font=('arial',18,'bold'), bg='black',fg='white',command=value_Cs)
btnCs.grid(row=0,column=0,padx=5,pady=5)
btnDs=Button(ABC2,height=6, width=6,bd=4, text="D#", font=('arial',18,'bold'), bg='black',fg='white',command=value_Ds)
btnDs.grid(row=0,column=1,padx=5,pady=5)


btnSpace2 = Button(ABC2, state=DISABLED, height=6, width=2,bd=4, bg='powder blue',relief=FLAT)
btnSpace2.grid(row=0,column=3,padx=0,pady=0)


btnFs=Button(ABC2,height=6, width=6,bd=4, text="F#", font=('arial',18,'bold'), bg='black',fg='white',command=value_Fs)
btnFs.grid(row=0,column=4,padx=5,pady=5)
btnGs=Button(ABC2,height=6, width=6,bd=4, text="G#", font=('arial',18,'bold'), bg='black',fg='white',command=value_Gs)
btnGs.grid(row=0,column=6,padx=5,pady=5)
btnAs=Button(ABC2,height=6, width=6,bd=4, text="A#", font=('arial',18,'bold'), bg='black',fg='white',command=value_As)
btnAs.grid(row=0,column=7,padx=5,pady=5)

btnSpace5 = Button(ABC2, state=DISABLED, height=6, width=2,bd=4, bg='powder blue',relief=FLAT)
btnSpace5.grid(row=0,column=9,padx=0,pady=0)


btnCs1=Button(ABC2,height=6, width=6,bd=4, text="C#", font=('arial',18,'bold'), bg='black',fg='white',command=value_Cs5)
btnCs1.grid(row=0,column=10,padx=5,pady=5)
btnDs1=Button(ABC2,height=6, width=6,bd=4, text="D#", font=('arial',18,'bold'), bg='black',fg='white',command=value_Ds5)
btnDs1.grid(row=0,column=11,padx=5,pady=5)

#======================================================================================================

btnC=Button(ABC3,height=8, width=6,bd=4, text="C", font=('arial',18,'bold'), bg='white',fg='black',command=value_C)
btnC.grid(row=0,column=0,padx=5,pady=5)
btnD=Button(ABC3,height=8, width=6,bd=4, text="D", font=('arial',18,'bold'), bg='white',fg='black',command=value_D)
btnD.grid(row=0,column=1,padx=5,pady=5)
btnE=Button(ABC3,height=8, width=6,bd=4, text="E", font=('arial',18,'bold'), bg='white',fg='black',command=value_E)
btnE.grid(row=0,column=2,padx=5,pady=5)

btnF=Button(ABC3,height=8, width=6,bd=4, text="F", font=('arial',18,'bold'), bg='white',fg='black',command=value_F)
btnF.grid(row=0,column=3,padx=5,pady=5)
btnG=Button(ABC3,height=8, width=6,bd=4, text="G", font=('arial',18,'bold'), bg='white',fg='black',command=value_G)
btnG.grid(row=0,column=4,padx=5,pady=5)
btnA=Button(ABC3,height=8, width=6,bd=4, text="A", font=('arial',18,'bold'), bg='white',fg='black',command=value_A)
btnA.grid(row=0,column=5,padx=5,pady=5)
btnB=Button(ABC3,height=8, width=6,bd=4, text="B", font=('arial',18,'bold'), bg='white',fg='black',command=value_B)
btnB.grid(row=0,column=6,padx=5,pady=5)

btnC1=Button(ABC3,height=8, width=6,bd=4, text="C", font=('arial',18,'bold'), bg='white',fg='black',command=value_C5)
btnC1.grid(row=0,column=7,padx=5,pady=5)
btnD1=Button(ABC3,height=8, width=6,bd=4, text="D", font=('arial',18,'bold'), bg='white',fg='black',command=value_D5)
btnD1.grid(row=0,column=8,padx=5,pady=5)
btnE1=Button(ABC3,height=8, width=6,bd=4, text="E", font=('arial',18,'bold'), bg='white',fg='black',command=value_E5)
btnE1.grid(row=0,column=9,padx=5,pady=5)
btnF1=Button(ABC3,height=8, width=6,bd=4, text="F", font=('arial',18,'bold'), bg='white',fg='black',command=value_F5)
btnF1.grid(row=0,column=10,padx=5,pady=5)


#======================================================================================================

root.mainloop()
